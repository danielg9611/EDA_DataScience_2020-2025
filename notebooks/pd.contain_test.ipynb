# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jobs = pd.read_csv('../data/salaries.csv')
jobs.shape
# Out:
# (88584, 11)

# %%
key_words = ('Data','Machine Learning', 'Analyst', 'Analysis', 'Analytics','Bussiness Intelligence', 'AI', 'BI', 'Decision Scientist','Computer Vision', 'NLP', 'ML', 'Artificial Intelligence','Deep Learning', 'ETL')

filtered_jobs1 = pd.DataFrame()

for key in key_words:
    filtered_jobs1 = pd.concat([filtered_jobs1,jobs[jobs['job_title'].str.contains(key)]])

filtered_jobs1

filtered_jobs1.shape
# Out:
# (64016, 11)

# %%
filtered_jobs2 = jobs[jobs['job_title'].str.contains('BI')]

filtered_jobs2
# Out:
#        work_year experience_level employment_type        job_title    salary  \
# 124         2025               EN              FT       BI Analyst    176150
# 125         2025               EN              FT       BI Analyst    112700
# 428         2025               SE              FT     BI Developer    130000
# 429         2025               SE              FT     BI Developer    110500
# 770         2025               EN              FT       BI Analyst    176150
# ...          ...              ...             ...              ...       ...
# 88355       2021               EN              FT  BI Data Analyst     55000
# 88395       2021               MI              FT  BI Data Analyst    100000
# 88398       2021               EX              FT  BI Data Analyst    150000
# 88414       2021               MI              FT  BI Data Analyst  11000000
# 88524       2020               MI              FT  BI Data Analyst     98000
#
# ...

# %%
filtered_jobs3 = jobs[jobs['job_title'].str.contains('|'.join(key_words))]

filtered_jobs3
# Out:
#        work_year experience_level employment_type                 job_title  \
# 5           2025               EN              FT              Data Analyst
# 6           2025               EN              FT              Data Analyst
# 11          2025               SE              FT            Data Scientist
# 12          2025               SE              FT            Data Scientist
# 17          2025               MI              FT         AI Data Scientist
# ...          ...              ...             ...                       ...
# 88579       2020               SE              FT            Data Scientist
# 88580       2021               MI              FT  Principal Data Scientist
# 88581       2020               EN              FT            Data Scientist
# 88582       2020               EN              CT     Business Data Analyst
# 88583       2021               SE              FT            Data Scientist
#
# ...
